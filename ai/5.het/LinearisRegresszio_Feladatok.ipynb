# %% [markdown]
# # MI
#
# # Feladatsor - Lineáris Regresszió Projekt
#
# Egy szerződéses munkát kapott egy e-kereskedelmi cégtől, amely ruhákat árusít online módon. Emellett van egy hagyományos boltjuk, ahol divat és öltözködési tanácsadással is foglalkoznak. Az ügyfelek bemennek az üzletbe, találkoznak egy stylisttal, majd otthon akár mobilalkalmazáson, akár weboldalon megrendelhetik a kívánt ruhákat.
#
# A cég szeretné eldönteni, hogy a továbbiakban mobilalkalmazására vagy a weboldalára összpontosítson. Segítsen nekik a döntésben azzal, hogy elvégzi az alábbi elemzést.

# %% [markdown]
# ___
# ## Importálás
# **Pandas, numpy, matplotlib, seaborn importálása, %matplotlib inline beállítása.
# (Az sklearn importálása később szükség szerint.)**

# %% [markdown]
# ## Az adatok
#
# A cég `EcommerceCustomers` csv fájljával fog dolgozni. Ebben vevők adatai szerepelnek: `Email`, `Address`, `Color`, valamint a következő numerikus adatok:
#
# * `Avg. Session Length`: A bolti tanácsadások átlagos ideje percben.
# * `Time on App`: A mobil alkalmazással töltött átlagos idő percben.
# * `Time on Website`: A weboldalontöltött átlagos idő percben.
# * `Length of Membership`: Hány éve tagja az ügyfél a vevői körnek.
# * `Yearly Amount Spent`: elköltött éves összeg.
#
# **1. Olvassa be az `EcommerceCustomers` fájlt DataFrame-ként `customers` néven és nézze meg az első 10 adatsort. Vizsgálja meg az adathalmazt az `info()` és a `describe()` metódusokkal.**

# %% [markdown]
# ## Feltáró adatelemzés
#
# A gyakorlat további részében a dataframe numerikus adatait vizsgálja.
# ___
# **2. Használja a `seaborn` pontdiagramját (`jointplot`), amellyel hasonlítsa össze a `Time on Website` és a `Yearly Amount Spent` tulajdonságokat.**

# %% [markdown]
# **3. Van korreláció az adatok között?**

# %% [markdown]
# Írja ide a válaszát (duplán kattintson a beíráshoz).

# %% [markdown]
# **4. Végezze el ugyanezt a `Time on App` és `Yearly Amount Spent` tulajdonságokkal,**

# %% [markdown]
# **5. majd a `Time on App` és a `Length of Membership` tulajdonsággal is.**

# %% [markdown]
# **6. Vizsgálja meg az adatok közötti összefüggést a teljes adathalmazon a [pairplot](https://stanford.edu/~mwaskom/software/seaborn/tutorial/axis_grids.html#plotting-pairwise-relationships-with-pairgrid-and-pairplot) használatával.**

# %% [markdown]
# **7. Az előző vizsgálatok alapján melyik tulajdonságra mondaná, hogy a legjobban korrelál a `Yearly Amount Spent` tulajdonsággal?**

# %% [markdown]
# Írja ide a válaszát (duplán kattintson a beíráshoz).

# %% [markdown]
# **8. A `corr()` függvény használatával is vizsgálja meg, hogy melyik tulajdonság korrelál legjobban a `Yearly Amount Spent` tulajdonsággal.**

# %% [markdown]
# ___
# ## Modell tanítása (illesztés) és tesztelése
#
# **Készítsen egy lineáris regressziós modellt.**
#
# **9. Ennek első lépéseként készítse elő a szükséges adatokat: `X` - az ügyfelek numerikus adatai (a `Yearly Amount Spent` kivételével), `y` - a `Yearly Amount Spent` attribútum.**

# %% [markdown]
# **10. Következő lépésként ossza fel az adatokat tanuló- és teszthalmazra. A teszthalmaz aránya 0.3 legyen. Állítsa be a random_state értékét 101-re.**

# %% [markdown]
# **11. Jelenítse meg a tanulóhalmazt és nézze meg annak méretét.**

# %% [markdown]
# ## Modell tanítása (illesztés)
#
# **12. Importálja a `LinearRegression` modellt a `sklearn.linear_model` könyvtárból. Készítsen egy `LinearRegression()` modell példányt `lm` névvel, majd illessze a modellt a tanulóhalmazon.**

# %% [markdown]
# **13. Jelenítse meg a kapott modell együtthatóit egyszerű tömbként és a következő formában is.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Teszt adatok értékének előrejelzése
# **14. Értékelje a modellt a tesztértékek előrejelzésével! Használja az `predict()` metódust az `X_test` teszthalmazzal.**

# %% [markdown]
# **15. Készítsen pontdiagramot a tesztadatok valós és a modellel becsült értékének összehasonlítására.**

# %% [markdown]
# ## A modell értékelése
#
# **16. Számítsa ki a `Mean Absolute Error`, `Mean Squared Error`, és a `Root Mean Squared Error` értékeket.**

# %% [markdown]
# ___
# ## Javaslat
# **Plusz kérdés:** Fogalmazza meg a válaszát az eredeti kérdésre, a mobilalkalmazásra vagy a weboldal fejlesztésére összpontosítson-e a cég? Vagy talán ez nem is igazán számít, és a tagság ideje (`Length of Membership`) az, ami igazán fontos?
#
# A válasz megfogalmazásához nézze meg a modell együtthatóit (de amennyiben szeretne, további elemzéseket is végezhet).

# %% [markdown]
# Írja ide a válaszát (duplán kattintson a beíráshoz).
